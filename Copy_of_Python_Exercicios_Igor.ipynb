# %% [markdown]
# <a href="https://colab.research.google.com/github/IgorAzure/-poiuytrdcvbnm-kl.kjhgvfcvbn/blob/main/Copy_of_Python_Exercicios_Igor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. O Limpador de Logs (Strings + Listas + Loop)
#
# Você recebeu uma lista "suja" de logs do servidor. Algumas linhas têm espaços em branco no começo/fim e outras são apenas avisos irrelevantes. Tarefa: Crie uma função que receba essa lista e retorne uma nova lista contendo apenas as mensagens que começam com a tag "[ERROR]", removendo os espaços extras das pontas.

# %%
logs = ["  [INFO] Sistema iniciado", " [ERROR] Falha na conexão  ", " [WARN] Uso de memória alto", "[ERROR] Timeout no DB "]
# Saída esperada: ['[ERROR] Falha na conexão', '[ERROR] Timeout no DB']

# %% [markdown]
# ### 2. Contador de Frequência (Dicionários + Loop)
#
# Este é um clássico de entrevistas. Tarefa: Dado um texto longo (string), conte quantas vezes cada palavra aparece. O resultado deve ser um dicionário onde a chave é a palavra e o valor é a contagem. Dica: Use .split() para transformar o texto em lista e um loop para preencher o dicionário.

# %%
texto = "python é legal python é fácil"
# Saída esperada: {'python': 2, 'é': 2, 'legal': 1, 'fácil': 1}

# %% [markdown]
# ### 3. Atualizador de Estoque (Dicionários + Lógica)
# Você tem um dicionário de estoque e uma lista de vendas realizadas. Tarefa: Crie uma função que receba o estoque atual e uma lista de produtos vendidos. Subtraia 1 unidade do estoque para cada venda. Se o produto não existir no estoque, ignore.

# %%
estoque = {"mouse": 10, "teclado": 5}
vendas = ["mouse", "mouse", "monitor", "teclado"]
# Saída esperada: {"mouse": 8, "teclado": 4}

# %% [markdown]
# ### 4. A Máscara de CPF (Slicing de Strings)
# Backend lida muito com formatação. Tarefa: Crie uma função que receba uma string contendo apenas números (ex: "12345678900") e retorne o CPF formatado com pontos e traço (ex: "123.456.789-00"). Dica: Use Fatiamento (Slicing) texto[inicio:fim] para pegar os pedaços e f-string para montar.

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 5. Calculadora de Frete Flexível (**kwargs)
# Tarefa: Crie uma função calcular_frete(valor_produto, **dados_entrega).
#
# * O frete base é R$ 10.00.
#
# * Se em **dados_entrega tiver estado="SP", adicione R$ 5.00.
#
# * Se tiver urgente=True, adicione R$ 20.00.
#
# * Retorne o valor total (produto + frete).

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 6. Validador de Senha (Lógica Booleana)
# Tarefa: Crie uma função validar_senha(senha) que retorna True ou False. Regras para ser True:
#
# 1. Ter pelo menos 8 caracteres.
#
# 2. Não pode ser apenas números (dica: .isdigit()).
#
# 3. Deve conter a palavra "admin" ou "123" (proibido) -> Se tiver, retorna False.

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 7. O "Junta-Tudo" (*args)
# Tarefa: Crie uma função chamada analisar_numeros que recebe qualquer quantidade de números usando *args. A função deve retornar um dicionário com:
#
# * "maior": O maior número.
#
# * "menor": O menor número.
#
# * "media": A média de todos. Dica: O Python tem funções max(), min() e sum() que ajudam muito.

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 8. Filtro de Produtos (Lista de Dicts)
# Tarefa: Você tem uma lista de dicionários (produtos). Cada produto tem nome, preco e categoria. Crie uma função que receba essa lista e uma categoria alvo. Retorne apenas os nomes dos produtos daquela categoria que custam menos de 50 reais.

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 9. Dias para o Evento (Datetime)
# Tarefa: Use a biblioteca datetime. Peça para o usuário digitar uma data futura (dia/mês/ano). Calcule e mostre quantos dias faltam de hoje até essa data. Dica: data_futura - data_hoje gera um objeto que tem a propriedade .days.

# %%
# Escreva seu código aqui

# %% [markdown]
# ### 10. Gerador de Username (Random + String)
# Tarefa: Crie um script que pede o Nome e o Sobrenome do usuário. Gere um username automático pegando:
#
# * As 3 primeiras letras do nome (minúsculas).
#
# * As 3 primeiras letras do sobrenome (minúsculas).
#
# * Um número aleatório entre 100 e 999. Ex: "Maria Silva" -> marsil482

# %%
# Escreva seu código aqui
